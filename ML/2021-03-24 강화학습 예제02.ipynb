# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

import tensorflow as tf
from tensorflow import keras

# Common imports
import numpy as np
import os

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# To get smooth animations
import matplotlib.animation as animation
mpl.rc('animation', html='jshtml')

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rl"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Introduction to OpenAI gym

# %% [markdown]
# In this notebook we will be using [OpenAI gym](https://gym.openai.com/), a great toolkit for developing and comparing Reinforcement Learning algorithms. It provides many environments for your learning *agents* to interact with. Let's start by importing `gym`:

# %%
import gym

# %%
def plot_environment(env, figsize=(5,4)):
    plt.figure(figsize=figsize)
    img = env.render(mode="rgb_array")
    plt.imshow(img)
    plt.axis("off")
    return img
def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    plt.close()
    return anim

# %% [markdown]
# # Neural Network Policies

# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 300


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False
        self.load_model = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = self.build_model()
        self.target_model = self.build_model()

        # 타깃 모델 초기화
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn_trained.h5")

    # 상태가 입력, 큐함수가 출력인 인공신경망 생성
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.zeros((self.batch_size, self.state_size))
        next_states = np.zeros((self.batch_size, self.state_size))
        actions, rewards, dones = [], [], []

        for i in range(self.batch_size):
            states[i] = mini_batch[i][0]
            actions.append(mini_batch[i][1])
            rewards.append(mini_batch[i][2])
            next_states[i] = mini_batch[i][3]
            dones.append(mini_batch[i][4])

        # 현재 상태에 대한 모델의 큐함수
        # 다음 상태에 대한 타깃 모델의 큐함수
        target = self.model.predict(states)
        target_val = self.target_model.predict(next_states)

        # 벨만 최적 방정식을 이용한 업데이트 타깃
        for i in range(self.batch_size):
            if dones[i]:
                target[i][actions[i]] = rewards[i]
            else:
                target[i][actions[i]] = rewards[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        self.model.fit(states, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)

# %%
def main():
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []

    for e in range(EPISODES):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            # 에피소드가 중간에 끝나면 -100 보상
            reward = reward if not done or score == 499 else -100

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            score += reward
            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()

                score = score if score == 500 else score + 100
                # 에피소드마다 학습 결과 출력
                scores.append(score)
                episodes.append(e)
                #pylab.plot(episodes, scores, 'b')
                pylab.savefig("cartpole_dqn.png")
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)

                # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    agent.model.save_weights("cartpole_dqn.h5")
                    return agent.model

# %%
model = main()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_19 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_22 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 12.0   memory length: 13   epsilon: 1.0
# episode: 1   score: 18.0   memory length: 32   epsilon: 1.0
# episode: 2   score: 8.0   memory length: 41   epsilon: 1.0
# episode: 3   score: 15.0   memory length: 57   epsilon: 1.0
# episode: 4   score: 15.0   memory length: 73   epsilon: 1.0
# episode: 5   score: 36.0   memory length: 110   epsilon: 1.0
# episode: 6   score: 8.0   memory length: 119   epsilon: 1.0
# episode: 7   score: 12.0   memory length: 132   epsilon: 1.0
# episode: 8   score: 18.0   memory length: 151   epsilon: 1.0
# episode: 9   score: 14.0   memory length: 166   epsilon: 1.0
# episode: 10   score: 47.0   memory length: 214   epsilon: 1.0
# episode: 11   score: 13.0   memory length: 228   epsilon: 1.0
# episode: 12   score: 14.0   memory length: 243   epsilon: 1.0
# episode: 13   score: 16.0   memory length: 260   epsilon: 1.0
# episode: 14   score: 21.0   memory length: 282   epsilon: 1.0
# episode: 15   score: 10.0   memory length: 293   epsilon: 1.0
# episode: 16   score: 40.0   memory length: 334   epsilon: 1.0
# episode: 17   score: 13.0   memory length: 348   epsilon: 1.0
# episode: 18   score: 30.0   memory length: 379   epsilon: 1.0
# episode: 19   score: 28.0   memory length: 408   epsilon: 1.0
# episode: 20   score: 15.0   memory length: 424   epsilon: 1.0
# episode: 21   score: 53.0   memory length: 478   epsilon: 1.0
# episode: 22   score: 25.0   memory length: 504   epsilon: 1.0
# episode: 23   score: 11.0   memory length: 516   epsilon: 1.0
# episode: 24   score: 10.0   memory length: 527   epsilon: 1.0
# episode: 25   score: 12.0   memory length: 540   epsilon: 1.0
# episode: 26   score: 15.0   memory length: 556   epsilon: 1.0
# episode: 27   score: 25.0   memory length: 582   epsilon: 1.0
# episode: 28   score: 25.0   memory length: 608   epsilon: 1.0
# episode: 29   score: 11.0   memory length: 620   epsilon: 1.0
score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 154   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 155   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 156   score: 359.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 157   score: 433.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 158   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 159   score: 314.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 160   score: 329.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 161   score: 11.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 162   score: 11.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 163   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 164   score: 10.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 165   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 166   score: 9.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 167   score: 11.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 168   score: 27.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 169   score: 305.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 170   score: 205.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 171   score: 17.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 172   score: 17.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 173   score: 14.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 174   score: 16.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 175   score: 15.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 176   score: 15.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 177   score: 18.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 178   score: 173.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 179   score: 228.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 180   score: 245.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 181   score: 244.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 182   score: 279.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 183   score: 291.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 184   score: 314.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 185   score: 352.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 186   score: 291.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 187   score: 289.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 188   score: 336.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 189   score: 343.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 190   score: 345.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 191   score: 329.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 192   score: 311.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 193   score: 356.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 194   score: 403.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 195   score: 373.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 196   score: 375.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 197   score: 417.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 198   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 199   score: 485.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 200   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 201   score: 472.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 202   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 203   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 204   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 205   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 206   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 207   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896

# %%
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# DQN 에이전트 생성
agent = DQNAgent(state_size, action_size)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_31 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 24)                120
# _________________________________________________________________
# dense_34 (Dense)             (None, 24)                600
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________

# %%
agent.model.load_weights("cartpole_dqn.h5")

# %% [markdown]
# * 에러 발생시
# pip install h5py==2.10.0

# %%
model = agent.model

# %%
def render_policy_net(model, n_max_steps=200, seed=42):
    frames = []
    env = gym.make("CartPole-v1")
    env.seed(seed)
    np.random.seed(seed)
    obs = env.reset()
    for step in range(n_max_steps):
        frames.append(env.render(mode="rgb_array"))
        left_proba = model.predict(obs.reshape(1, -1))
        action = np.argmax(left_proba)
        obs, reward, done, info = env.step(action)
        if done:
            break
    env.close()
    return frames

# %%
frames = render_policy_net(model, 500)

# %%
plot_animation(frames)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img2ac316673fa3429da30b3c8645c82714">
#   <div class="anim-controls">
#     <input id="_anim_slider2ac316673fa3429da30b3c8645c82714" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim2ac316673fa3429da30b3c8645c82714.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim2ac316673fa3429da30b3c8645c82714.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim2ac316673fa3429da30b3c8645c82714.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim2ac316673fa3429da30b3c8645c82714.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim2ac316673fa3429da30b3c8645c82714.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim2ac316673fa3429da30b3c8645c82714.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim2ac316673fa3429da30b3c8645c82714.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim2ac316673fa3429da30b3c8645c82714.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim2ac316673fa3429da30b3c8645c82714.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim2ac316673fa3429da30b3c8645c82714.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select2ac316673fa3429da30b3c8645c82714"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_2ac316673fa3429da30b3c8645c82714"
#              checked>
#       <label for="_anim_radio1_2ac316673fa3429da30b3c8645c82714">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_2ac316673fa3429da30b3c8645c82714"
#              >
#       <label for="_anim_radio2_2ac316673fa3429da30b3c8645c82714">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_2ac316673fa3429da30b3c8645c82714"
#              >
#       <label for="_anim_radio3_2ac316673fa3429da30b3c8645c82714">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2ac316673fa3429da30b3c8645c82714";
#     var slider_id = "_anim_slider2ac316673fa3429da30b3c8645c82714";
#     var loop_select_id = "_anim_loop_select2ac316673fa3429da30b3c8645c82714";
#     var frames = new Array(500);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAHPklEQVR4nO3dzWtddR7H8e9JbpO0vTbxToh3EHXAB4QZUVy50I0rkS66dzF/\
# RaH/gWDXhf4Ps8l6hln5QFFbZwTBqAMWNY3Shj7EtknTHBczDJQM2GTMOf3cvF67++PenE8W4Z2b\
# 3Js0bdsWAKSZ6nsAAOyHgAEQScAAiCRgAEQSMAAiCRgAkQQMgEgCBkAkAQMgkoABEEnAAIgkYABE\
# EjAAIgkYAJEEDIBIAgZAJAEDIJKAA
